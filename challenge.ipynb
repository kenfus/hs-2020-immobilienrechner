# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
csv_data = pd.read_csv('immo_dev_data.csv')

# %% [markdown]
# #  Explorative Datenanalyse (1/4)
#
# Verschaffe dir einen Überblick über den Trainingsdatensatz durch Visualisierung und Verwendung von Methoden der deskriptiven Statistik.
#
# Mit Hinblick auf die Aufgabenstellungen 2 und 3 interessieren uns besonders Einflüsse auf die Attribute `PurchasePrice` und `GroupNameDe`.
#
# Was lässt sich weiter über die Abhängikeiten der Attribute sagen?
#
# **Abgabe**
#
# Notebook und daraus erstellter Bericht (ohne Code) als pdf.

# %%
# your code here

# %% [markdown]
# # Vorhersage des Immobilienpreises (1/2)
#
# Ziel dieser Teilaufgabe ist die Vorhersage des Preises (Attribut `PurchasePrice`).
#
# Die Aufgabenstellung ist zwei Teilschritte gegliedert, die Verständnisgewinn und erfolgreiches Lösen der Aufgabenstellung unterstützen sollen:

# %% [markdown]
# ## Einfache lineare Regression und Residuenanalyse
#
# Verwende ein einfaches lineares Modell zur Vorhersage von `PurchasePrice` mit dem Attribut `AreaLiving`.
#
# Entwickle das Modell in einem Notebook. Untersuche dabei ob die Annahmen eines linearen Modells erfüllt sind mit geeigneten Darstellungen. Wie können Variablen-Transformationen verwendet werden, um die Modellvoraussetzungen besser zu erfüllen und das Modell zu verbessern?
#
# Rapportiere und diskutiere die erreichte Genauigkeit der Vorhersage mit mehreren sinnvollen Metriken und auf unabhängigen Testdaten.
#
# **Abgabe**
#
# Notebook und daraus erstellter Bericht (ohne Code) als pdf.

# %%
px.scatter(csv_data, x = 'AreaLiving', y = 'PurchasePrice', width=600, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="06db270f-d281-4c3e-8067-9b1ecb35fae8" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06db270f-d281-4c3e-8067-9b1ecb35fae8")) {                    Plotly.newPlot(                        "06db270f-d281-4c3e-8067-9b1ecb35fae8",                        [{"hovertemplate": "AreaLiving=%{x}<br>PurchasePrice=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [140.0, 143.0, 160.0, 351.0, 400.0, 314.0, 400.0, 117.0, 160.0, 137.0, 351.0, 150.0, 351.0, 213.0, 307.0, 208.0, 233.0, 234.0, 260.0, 105.0, 160.0, 210.0, 216.0, 180.0, 110.0, 260.0, 290.0, 434.0, 230.0, 155.0, 266.0, 262.0, 260.0, 200.0, 300.0, 88.0, 192.0, 270.0, 154.0, 200.0, 160.0, 220.0, 211.0, 140.0, 177.0, 135.0, 333.0, 195.0, 125.0, 192.0, 111.0, 150.0, 185.0, 200.0, 250.0, 486.0, 200.0, 150.0, 160.0, 100.0, 120.0, 211.0, 150.0, 75.0, 263.0, 580.0, 220.0, 240.0, 162.0, 287.0, 220.0, 500.0, 180.0, 192.0, 159.0, 140.0, 189.0, 245.0, 221.0, 150.0, 157.0, 165.0, 148.0, 180.0, 155.0, 370.0, 206.0, 586.0, 336.0, 148.0, 180.0, 100.0, 234.0, 232.0, 130.0, 330.0, 347.0, 309.0, 190.0, 120.0, 158.0, 167.0, 240.0, 184.0, 120.0, 192.0, 160.0, 152.0, 200.0, 221.0, 170
0, 194.0, 182.0, 220.0, 120.0, 130.0, 264.0, 230.0, 180.0, 217.0, 160.0, 150.0, 416.0, 210.0, 330.0, 200.0, 165.0, 110.0, 168.0, 66.0, 130.0, 216.0, 370.0, 158.0, 130.0, 270.0, 100.0, 180.0, 200.0, 180.0, 100.0, 128.0, 175.0, 208.0, 130.0, 100.0, 318.0, 240.0, 242.0, 310.0, 275.0, 100.0, 90.0, 240.0, 105.0, 140.0, 150.0, 250.0, 170.0, 174.0, 210.0, 280.0, 100.5, 160.0, 153.0, 170.0, 140.0, ...

# %% [markdown]
# ## Bestmögliches Regressionsmodell – kaggle-Contest
#
# Entwickle mit beliebigen Algorithmen das bestmögliche Modell im Sinne des MAPE. Vegleiche dabei mindestens drei algorithmische Ansätze, wobei ein multiples lineares Modell Teil davon sein soll als Benchmark. Untersuche die ‘Variable Importance’ für dein bestes Modell.
#
# **Abgabe**
#
# Notebook und daraus erstellter Bericht (ohne Code) als pdf, welche die Entwicklung deines besten Modells, sowie der zwei weiteren Modelle dokumentiert, inklusive verwendeter Features, Preprocessing, Model Selection Prozess und Untersuchung der ‘Variable Importance’.
#
# Eingabe der Vorhersage des Preises für den Testdatensatz mit deinem bestmöglichen Modell auf kaggle.

# %% [markdown]
# ## Bestmögliches Regressionsmodell – kaggle-Contest
#
# Entwickle mit beliebigen Algorithmen das bestmögliche Modell im Sinne des MAPE. Vegleiche dabei mindestens drei algorithmische Ansätze, wobei ein multiples lineares Modell Teil davon sein soll als Benchmark. Untersuche die ‘Variable Importance’ für dein bestes Modell.
#
# **Abgabe**
#
# Notebook und daraus erstellter Bericht (ohne Code) als pdf, welche die Entwicklung deines besten Modells, sowie der zwei weiteren Modelle dokumentiert, inklusive verwendeter Features, Preprocessing, Model Selection Prozess und Untersuchung der ‘Variable Importance’.
#
# Eingabe der Vorhersage des Preises für den Testdatensatz mit deinem bestmöglichen Modell auf kaggle.

# %%
# your code here

# %% [markdown]
# ## Webservice
#
# Erstelle einen Web-Service mit deinem besten Modell, welche via http-Request angefragt werden kann und für ein bestimmtes Objekt eine Preis-Vorhersage zurückgibt.
#
# **Abgabe**
#
# Skript, welches den Web-Service startet und eine kurze Anleitung, wie dieser zu verwenden ist.

# %%
# your code here

# %% [markdown]
# # Klassifikation des Objekttyps (1/4)
#
# Entwickle und vergleiche drei sinnvolle Modelle zur Klassifikation von Immobilien Objekten hinsichtlich `GroupNameDe`.
#
# Was sind sinnvolle Metriken zur Messung der Genaugikeit der Vorhersage im vorliegenden Fall?
#
# Rapportiere diese Metrik(en) mit einer Abschätzung des Fehlers für alle drei Modelle.
#
# **Abgabe**
#
# Notebook und daraus erstellter Bericht (ohne Code) als pdf.

# %%
# your code here

# %% [markdown]
# # Abschliessende Austauschrunde
#
# Teil des Challenge ist eine Austauschrunde zum Schluss. Hier stellst du und deine Gruppe deine/eure Arbeit vor und berichtet über Einsichten, Erfolge und Herausforderungen.
